# %%
import cv2
import os
import csv

# Chemin vers les vidéos
violence_path = "C:/Users/LENOVO/Documents/Psir/Réalisation_experience/Video-Surveillance/data/Real Life Violence Dataset/Violence"
non_violence_path = "C:/Users/LENOVO/Documents/Psir/Réalisation_experience/Video-Surveillance/data/Real Life Violence Dataset/NonViolence"

# Dossier où enregistrer les frames extraites
output_dir = 'C:/Temp/test_frames' #dossier temporaire pour les images extraitres 

# Créer les dossiers s'ils n'existent pas
os.makedirs(os.path.join(output_dir, "violence"), exist_ok=True)
os.makedirs(os.path.join(output_dir, "non_violence"), exist_ok=True)

# Fichier CSV pour stocker les métadonnées
csv_file = os.path.join(output_dir, "metadata.csv")
with open(csv_file, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['image_path', 'label'])  # Header du CSV

    # Fonction pour traiter une vidéo
    def process_video(video_path, label):
        video_name = os.path.basename(video_path)
        cap = cv2.VideoCapture(video_path)
        success, frame = cap.read()
        if not success or frame is None:
            print(f" Frame vide pour : {video_path}")
            cap.release()
            return

        frame_filename = f"{video_name.split('.')[0]}_frame0.jpg"
        label_folder = "violence" if label == 1 else "non_violence"
        output_path = os.path.join(output_dir, label_folder, frame_filename)

        try:
            # Normaliser le chemin
            output_path = os.path.normpath(output_path)

            # Supprimer le fichier s'il existe
            if os.path.exists(output_path):
                os.remove(output_path)

            # Sauvegarder l'image
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            success = cv2.imwrite(output_path, frame)
            if success:
                print(f" Image enregistrée : {output_path}")
                writer.writerow([output_path, label])
            else:
                print(f" Échec de sauvegarde pour : {output_path}")
        except Exception as e:
            print(f" Erreur pour {output_path} : {e}")
        cap.release()

    # Traiter les vidéos de violence (label 1)
    for filename in os.listdir(violence_path):
        if filename.endswith(".mp4"):
            full_path = os.path.join(violence_path, filename)
            process_video(full_path, label=1)

    # Traiter les vidéos non violentes (label 0)
    for filename in os.listdir(non_violence_path):
        if filename.endswith(".mp4"):
            full_path = os.path.join(non_violence_path, filename)
            process_video(full_path, label=0)

print("\n✅ Traitement terminé.")
# Out:
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_1_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_10_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_100_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_1000_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_101_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_102_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_103_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_104_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_105_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_106_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_107_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_108_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_109_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_11_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_110_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_111_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_112_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_113_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_114_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_115_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_116_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_117_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_118_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_119_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_12_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_120_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_121_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_122_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_123_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_124_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_125_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_126_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_127_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_128_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_129_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_13_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_130_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_131_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_132_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_133_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_134_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_135_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_136_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_137_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_138_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_139_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_14_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_140_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_141_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_142_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_143_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_144_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_145_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_146_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_147_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_148_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_149_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_15_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_150_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_151_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_152_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_153_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_154_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_155_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_156_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_157_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_158_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_159_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_16_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_160_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_161_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_162_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_163_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_164_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_165_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_166_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_167_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_168_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_169_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_17_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_170_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_171_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_172_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_173_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_174_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_175_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_176_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_177_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_178_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_179_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_18_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_180_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_181_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_182_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_183_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_184_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_185_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_186_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_187_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_188_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_189_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_19_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_190_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_191_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_192_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_193_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_194_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_195_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_196_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_197_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_198_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_199_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_2_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_20_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V_200_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\violence\V
frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_93_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_930_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_931_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_932_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_933_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_934_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_935_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_936_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_937_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_938_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_939_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_94_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_940_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_941_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_942_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_943_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_944_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_945_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_946_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_947_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_948_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_949_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_95_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_950_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_951_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_952_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_953_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_954_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_955_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_956_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_957_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_958_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_959_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_96_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_960_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_961_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_962_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_963_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_964_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_965_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_966_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_967_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_968_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_969_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_97_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_970_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_971_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_972_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_973_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_974_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_975_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_976_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_977_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_978_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_979_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_98_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_980_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_981_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_982_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_983_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_984_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_985_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_986_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_987_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_988_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_989_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_99_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_990_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_991_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_992_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_993_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_994_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_995_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_996_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_997_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_998_frame0.jpg
# ✅ Image enregistrée : C:\Temp\test_frames\non_violence\NV_999_frame0.jpg
#
# ✅ Traitement terminé.

# %%
#tests sur une image pour eviter les erreus de lecture de vidéo 
import cv2
import os

# Chemin de test vers une vidéo
video_path = 'C:/Users/LENOVO/Documents/Psir/Réalisation_experience/Video-Surveillance/data/Real Life Violence Dataset/Violence/V_1.mp4'

# Chemin de sauvegarde d'une image
save_dir = 'C:/Temp/test_frames'

os.makedirs(save_dir, exist_ok=True)
save_path = os.path.join(save_dir, 'frame0.png')

# Lecture de la vidéo
cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()

if frame is None:
    print("La frame est vide (None)")
else:
    print("Frame lue avec succès, dimensions :", frame.shape)


if not cap.isOpened():
    print("Impossible d’ouvrir la vidéo.")
elif not ret:
    print("Impossible de lire la première frame.")
else:
    success = cv2.imwrite(save_path, frame)
    if success and os.path.exists(save_path):
        print(f"Image bien sauvegardée à : {save_path}")
    else:
        print("Échec lors de la sauvegarde de l’image.")

cap.release()
# Out:
# Frame lue avec succès, dimensions : (1080, 1920, 3)
# Image bien sauvegardée à : C:/Temp/test_frames\frame0.png

# %%
import pandas as pd
import os
#on met à jour le csv
# Charger le CSV existant
csv_path = r'C:/Users/LENOVO/Documents/Psir/Réalisation_experience/Video-Surveillance/data/metadata.csv'
df = pd.read_csv(csv_path)

# Modifier la colonne contenant le chemin vers les images 
# Remplace par le chemin absolu correct
new_base_path = r'C:/Users/LENOVO/Documents/Psir/Réalisation_experience/Video-Surveillance/data/extractFrames'

df['image_path'] = df['image_path'].apply(lambda x: os.path.join(new_base_path, os.path.basename(x)))

# Sauvegarde le fichier CSV modifié
df.to_csv(csv_path, index=False)

print(" Chemins mis à jour dans le CSV avec succès.")
# Out:
#  Chemins mis à jour dans le CSV avec succès.

# %%
pip install labelImg
# Out:
# Collecting labelImg
#   Downloading labelImg-1.8.6.tar.gz (247 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyqt5 (from labelImg)
#   Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# Collecting lxml (from labelImg)
#   Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting PyQt5-sip<13,>=12.15 (from pyqt5->labelImg)
#   Downloading PyQt5_sip-12.17.0-cp311-cp311-win_amd64.whl.metadata (492 bytes)
# Collecting PyQt5-Qt5<5.16.0,>=5.15.2 (from pyqt5->labelImg)
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------- ----------------------------- 1.0/3.8 MB 5.0 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.8 MB 4.9 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 4.8 MB/s eta 0:00:00
# Downloading PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.3/6.9 MB 6.7 MB/s eta 0:00:01
#    ------------- -------------------------- 2.4/6.9 MB 5.6 MB/s eta 0:00:01
#    ------------------- -------------------- 3.4/6.9 MB 5.4 MB/s eta 0:00:01
#    ------------------------- -------------- 4.5/6.9 MB 5.5 MB/s eta 0:00:01
#    -------------------------------- ------- 5.5/6.9 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 6.9/6.9 MB 5.2 MB/s eta 0:00:00
# Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
#    ---------------------------------------- 0.0/50.1 MB ? eta -:--:--
#     --------------------------------------- 1.0/50.1 MB 6.3 MB/s eta 0:00:08
#    - -------------------------------------- 2.4/50.1 MB 5.6 MB/s eta 0:00:09
#    -- ------------------------------------- 3.7/50.1 MB 5.7 MB/s eta 0:00:09
#    --- ------------------------------------ 4.7/50.1 MB 5.7 MB/s eta 0:00:08
#    ---- ----------------------------------- 6.0/50.1 MB 5.7 MB/s eta 0:00:08
#    ----- ---------------------------------- 7.1/50.1 MB 5.6 MB/s eta 0:00:08
#    ------ --------------------------------- 8.4/50.1 MB 5.6 MB/s eta 0:00:08
#    ------- -------------------------------- 9.4/50.1 MB 5.5 MB/s eta 0:00:08
#    -------- ------------------------------- 10.7/50.1 MB 5.5 MB/s eta 0:00:08
#    --------- ------------------------------ 12.1/50.1 MB 5.6 MB/s eta 0:00:07
#    ---------- ----------------------------- 13.1/50.1 MB 5.6 MB/s eta 0:00:07
#    ----------- ---------------------------- 14.4/50.1 MB 5.6 MB/s eta 0:00:07
#    ------------ --------------------------- 15.7/50.1 MB 5.6 MB/s eta 0:00:07
#    ------------- -------------------------- 16.8/50.1 MB 5.5 MB/s eta 0:00:07
#    -------------- ------------------------- 17.8/50.1 MB 5.5 MB/s eta 0:00:06
#    --------------- ------------------------ 19.1/50.1 MB 5.5 MB/s eta 0:00:06
#    ---------------- ----------------------- 20.2/50.1 MB 5.5 MB/s eta 0:00:06
#    ----------------- ---------------------- 21.5/50.1 MB 5.5 MB/s eta 0:00:06
#    ------------------ --------------------- 22.8/50.1 MB 5.6 MB/s eta 0:00:05
#    ------------------- -------------------- 24.4/50.1 MB 5.5 MB/s eta 0:00:05
#    -------------------- ------------------- 25.7/50.1 MB 5.5 MB/s eta 0:00:05
#    --------------------- ------------------ 27.0/50.1 MB 5.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 28.0/50.1 MB 5.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 29.1/50.1 MB 5.5 MB/s eta 0:00:04
#    ------------------------ --------------- 30.1/50.1 MB 5.5 MB/s eta 0:00:04
#    ------------------------ --------------- 30.9/50.1 MB 5.4 MB/s eta 0:00:04
#    ------------------------- -------------- 32.2/50.1 MB 5.4 MB/s eta 0:00:04
#    -------------------------- ------------- 33.6/50.1 MB 5.4 MB/s eta 0:00:04
#    --------------------------- ------------ 34.6/50.1 MB 5.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 35.7/50.1 MB 5.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 37.0/50.1 MB 5.4 MB/s eta 0:00:03
#    ------------------------------ --------- 38.3/50.1 MB 5.5 MB/s eta 0:00:03
#    ------------------------------- -------- 39.3/50.1 MB 5.4 MB/s eta 0:00:02
#    -------------------------------- ------- 40.6/50.1 MB 5.5 MB/s eta 0:00:02
#    --------------------------------- ------ 41.7/50.1 MB 5.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 43.0/50.1 MB 5.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 44.3/50.1 MB 5.5 MB/s eta 0:00:02
#    ------------------------------------ --- 45.4/50.1 MB 5.5 MB/s eta 0:00:01
#    ------------------------------------- -- 46.7/50.1 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 48.0/50.1 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 48.5/50.1 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------------  49.8/50.1 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------  50.1/50.1 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 50.1/50.1 MB 5.3 MB/s eta 0:00:00
# Downloading PyQt5_sip-12.17.0-cp311-cp311-win_amd64.whl (59 kB)
# Building wheels for collected packages: labelImg
#   Building wheel for labelImg (setup.py): started
#   Building wheel for labelImg (setup.py): finished with status 'done'
#   Created wheel for labelImg: filename=labelImg-1.8.6-py2.py3-none-any.whl size=261578 sha256=162f69d5e7882adce5f2c4752706652c1cc8f0a05da0e5baf8d148e32f76158e
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\79\90\db\e0700438d3647c0209061d77992c901d3c786a56fec574ac86
# Successfully built labelImg
# Installing collected packages: PyQt5-Qt5, PyQt5-sip, lxml, pyqt5, labelImg
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.17.0 labelImg-1.8.6 lxml-5.4.0 pyqt5-5.15.11
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1
# [notice] To update, run: C:\Users\LENOVO\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip show labelImg
# Out:
# Name: labelImgNote: you may need to restart the kernel to use updated packages.
#
# Version: 1.8.6
# Summary: LabelImg is a graphical image annotation tool and label object bounding boxes in images
# Home-page: https://github.com/tzutalin/labelImg
# Author: TzuTa Lin
# Author-email: tzu.ta.lin@gmail.com
# License: MIT license
# Location: C:\Users\LENOVO\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages
# Requires: lxml, pyqt5
# Required-by:
